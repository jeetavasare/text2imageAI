# %%
import torch
from imagen_pytorch import Unet, NullUnet, Imagen

# unet for imagen

unet1 = NullUnet()  # add a placeholder "null" unet for the base unet

unet2 = Unet(
    dim = 32,
    cond_dim = 512,
    dim_mults = (1, 2, 4, 8),
    num_resnet_blocks = (2, 4, 8, 8),
    layer_attns = (False, False, False, True),
    layer_cross_attns = (False, False, False, True)
)

# imagen, which contains the unets above (base unet and super resoluting ones)

imagen = Imagen(
    unets = (unet1, unet2),
    image_sizes = (64, 256),
    timesteps = 250,
    cond_drop_prob = 0.1
).cuda()

# mock images (get a lot of this) and text encodings from large T5

text_embeds = torch.randn(4, 256, 768).cuda()
images = torch.randn(4, 3, 256, 256).cuda()

# feed images into imagen, training each unet in the cascade

loss = imagen(images, text_embeds = text_embeds, unet_number = 2)
loss.backward()

# do the above for many many many many steps
# now you can sample an image based on the text embeddings as well as low resolution images

lowres_images = torch.randn(3, 3, 64, 64).cuda()  # starting un-resoluted images

images = imagen.sample(
    texts = [
        'a whale breaching from afar',
        'young girl blowing out candles on her birthday cake',
        'fireworks with blue and green sparkles'
    ],
    start_at_unet_number = 2,              # start at unet number 2
    start_image_or_video = lowres_images,  # pass in low resolution images to be resoluted
    cond_scale = 3.)

images.shape # (3, 3, 256, 256)
# Out:
# Collecting imagen-pytorch
#   Obtaining dependency information for imagen-pytorch from https://files.pythonhosted.org/packages/35/2e/e8d6884c700dfc4abcb149f6e628707ea8d8cf058e13e66547bc9f20cb48/imagen_pytorch-1.26.2-py3-none-any.whl.metadata
#   Downloading imagen_pytorch-1.26.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting accelerate>=0.23.0 (from imagen-pytorch)
#   Obtaining dependency information for accelerate>=0.23.0 from https://files.pythonhosted.org/packages/1b/da/24a54b9205fce3bdbaad521c35944d0b0a2d292ac5ae921e484b76312b43/accelerate-0.27.2-py3-none-any.whl.metadata
#   Downloading accelerate-0.27.2-py3-none-any.whl.metadata (18 kB)
# Collecting beartype (from imagen-pytorch)
#   Obtaining dependency information for beartype from https://files.pythonhosted.org/packages/81/4a/97ea8a5afb289a25ae7db3b3ef68f0aad892bc1756be94565154877b173e/beartype-0.17.2-py3-none-any.whl.metadata
#   Downloading beartype-0.17.2-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: click in c:\users\jeet\anaconda3\lib\site-packages (from imagen-pytorch) (8.0.4)
# Requirement already satisfied: datasets in c:\users\jeet\anaconda3\lib\site-packages (from imagen-pytorch) (2.12.0)
# Collecting einops>=0.7.0 (from imagen-pytorch)
#   Obtaining dependency information for einops>=0.7.0 from https://files.pythonhosted.org/packages/29/0b/2d1c0ebfd092e25935b86509a9a817159212d82aa43d7fb07eca4eeff2c2/einops-0.7.0-py3-none-any.whl.metadata
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting ema-pytorch>=0.0.3 (from imagen-pytorch)
#   Obtaining dependency information for ema-pytorch>=0.0.3 from https://files.pythonhosted.org/packages/17/22/355c17c2ccf14ee365274bfa8223b55767c269a85ceaf3d85a3e481185c9/ema_pytorch-0.4.2-py3-none-any.whl.metadata
#   Downloading ema_pytorch-0.4.2-py3-none-any.whl.metadata (715 bytes)
# Requirement already satisfied: fsspec in c:\users\jeet\anaconda3\lib\site-packages (from imagen-pytorch) (2023.4.0)
# Collecting kornia (from imagen-pytorch)
#   Obtaining dependency information for kornia from https://files.pythonhosted.org/packages/34/5b/f1ee7ec4826cdd34f95f822c975f5a889c99dfd29491cebfc71db03b40e8/kornia-0.7.1-py2.py3-none-any.whl.metadata
#   Downloading kornia-0.7.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in c:\users\jeet\anaconda3\lib\site-packages (from imagen-pytorch) (1.24.3)
# Requirement already satisfied: packaging in c:\users\jeet\anaconda3\lib\site-packages (from imagen-pytorch) (23.1)
# Requirement already satisfied: pillow in c:\users\jeet\anaconda3\lib\site-packages (from imagen-pytorch) (9.4.0)
# Collecting pydantic>=2 (from imagen-pytorch)
#   Obtaining dependency information for pydantic>=2 from https://files.pythonhosted.org/packages/db/dc/afecbd9650f486889181c6d1a0d675b580c06253ea7e304588e4c7485bdb/pydantic-2.6.1-py3-none-any.whl.metadata
#   Downloading pydantic-2.6.1-py3-none-any.whl.metadata (83 kB)
#      ---------------------------------------- 0.0/83.5 kB ? eta -:--:--
#      ---------------------------------------  81.9/83.5 kB 2.2 MB/s eta 0:00:01
#      ---------------------------------------- 83.5/83.5 kB 1.6 MB/s eta 0:00:00
# Collecting pytorch-warmup (from imagen-pytorch)
#   Obtaining dependency information for pytorch-warmup from https://files.pythonhosted.org/packages/b9/89/adb6809ac3d587a725ff1d0cd79e0a75bc3a20c3fa1476a917026838f1d0/pytorch_warmup-0.1.1-py3-none-any.whl.metadata
#   Downloading pytorch_warmup-0.1.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting sentencepiece (from imagen-pytorch)
#   Obtaining dependency information for sentencepiece from https://files.pythonhosted.org/packages/a2/f6/587c62fd21fc988555b85351f50bbde43a51524caafd63bc69240ded14fd/sentencepiece-0.2.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading sentencepiece-0.2.0-cp311-cp311-win_amd64.whl.metadata (8.3 kB)
# Requirement already satisfied: torch>=1.6 in c:\users\jeet\anaconda3\lib\site-packages (from imagen-pytorch) (2.1.2)
# Collecting torchvision (from imagen-pytorch)
#   Obtaining dependency information for torchvision from https://files.pythonhosted.org/packages/b5/56/38e892200f8638032b64f6fc8660049f0d00ccba086cf1dcb884bd6370d2/torchvision-0.17.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading torchvision-0.17.0-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: transformers in c:\users\jeet\anaconda3\lib\site-packages (from imagen-pytorch) (4.32.1)
# Requirement already satisfied: tqdm in c:\users\jeet\anaconda3\lib\site-packages (from imagen-pytorch) (4.65.0)
# Requirement already satisfied: psutil in c:\users\jeet\anaconda3\lib\site-packages (from accelerate>=0.23.0->imagen-pytorch) (5.9.0)
# Requirement already satisfied: pyyaml in c:\users\jeet\anaconda3\lib\site-packages (from accelerate>=0.23.0->imagen-pytorch) (6.0)
# Requirement already satisfied: huggingface-hub in c:\users\jeet\anaconda3\lib\site-packages (from accelerate>=0.23.0->imagen-pytorch) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\jeet\anaconda3\lib\site-packages (from accelerate>=0.23.0->imagen-pytorch) (0.3.2)
# Collecting annotated-types>=0.4.0 (from pydantic>=2->imagen-pytorch)
#   Obtaining dependency information for annotated-types>=0.4.0 from https://files.pythonhosted.org/packages/28/78/d31230046e58c207284c6b2c4e8d96e6d3cb4e52354721b944d3e1ee4aa5/annotated_types-0.6.0-py3-none-any.whl.metadata
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.16.2 (from pydantic>=2->imagen-pytorch)
#   Obtaining dependency information for pydantic-core==2.16.2 from https://files.pythonhosted.org/packages/cb/5a/c8fdc6369f7b00ef15c97ec5c2d092e10f112982ea3747f364f2141e3702/pydantic_core-2.16.2-cp311-none-win_amd64.whl.metadata
#   Downloading pydantic_core-2.16.2-cp311-none-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\jeet\anaconda3\lib\site-packages (from pydantic>=2->imagen-pytorch) (4.7.1)
# Requirement already satisfied: filelock in c:\users\jeet\anaconda3\lib\site-packages (from torch>=1.6->imagen-pytorch) (3.9.0)
# Requirement already satisfied: sympy in c:\users\jeet\anaconda3\lib\site-packages (from torch>=1.6->imagen-pytorch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\jeet\anaconda3\lib\site-packages (from torch>=1.6->imagen-pytorch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\jeet\anaconda3\lib\site-packages (from torch>=1.6->imagen-pytorch) (3.1.2)
# Requirement already satisfied: colorama in c:\users\jeet\anaconda3\lib\site-packages (from click->imagen-pytorch) (0.4.6)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\jeet\anaconda3\lib\site-packages (from datasets->imagen-pytorch) (11.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in c:\users\jeet\anaconda3\lib\site-packages (from datasets->imagen-pytorch) (0.3.6)
# Requirement already satisfied: pandas in c:\users\jeet\anaconda3\lib\site-packages (from datasets->imagen-pytorch) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\jeet\anaconda3\lib\site-packages (from datasets->imagen-pytorch) (2.31.0)
# Requirement already satisfied: xxhash in c:\users\jeet\anaconda3\lib\site-packages (from datasets->imagen-pytorch) (2.0.2)
# Requirement already satisfied: multiprocess in c:\users\jeet\anaconda3\lib\site-packages (from datasets->imagen-pytorch) (0.70.14)
# Requirement already satisfied: aiohttp in c:\users\jeet\anaconda3\lib\site-packages (from datasets->imagen-pytorch) (3.8.5)
# Requirement already satisfied: responses<0.19 in c:\users\jeet\anaconda3\lib\site-packages (from datasets->imagen-pytorch) (0.13.3)
# Collecting torch>=1.6 (from imagen-pytorch)
#   Obtaining dependency information for torch>=1.6 from https://files.pythonhosted.org/packages/58/b8/51b956c2da9729390a3080397cd2f31171394543af7746681466e372f69a/torch-2.2.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading torch-2.2.0-cp311-cp311-win_amd64.whl.metadata (26 kB)
# Collecting typing-extensions>=4.6.1 (from pydantic>=2->imagen-pytorch)
#   Obtaining dependency information for typing-extensions>=4.6.1 from https://files.pythonhosted.org/packages/b7/f4/6a90020cd2d93349b442bfcb657d0dc91eee65491600b2cb1d388bc98e6b/typing_extensions-4.9.0-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\jeet\anaconda3\lib\site-packages (from transformers->imagen-pytorch) (2022.7.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\jeet\anaconda3\lib\site-packages (from transformers->imagen-pytorch) (0.13.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jeet\anaconda3\lib\site-packages (from aiohttp->datasets->imagen-pytorch) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\jeet\anaconda3\lib\site-packages (from aiohttp->datasets->imagen-pytorch) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jeet\anaconda3\lib\site-packages (from aiohttp->datasets->imagen-pytorch) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\jeet\anaconda3\lib\site-packages (from aiohttp->datasets->imagen-pytorch) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\jeet\anaconda3\lib\site-packages (from aiohttp->datasets->imagen-pytorch) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\jeet\anaconda3\lib\site-packages (from aiohttp->datasets->imagen-pytorch) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\jeet\anaconda3\lib\site-packages (from aiohttp->datasets->imagen-pytorch) (1.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jeet\anaconda3\lib\site-packages (from requests>=2.19.0->datasets->imagen-pytorch) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jeet\anaconda3\lib\site-packages (from requests>=2.19.0->datasets->imagen-pytorch) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jeet\anaconda3\lib\site-packages (from requests>=2.19.0->datasets->imagen-pytorch) (2023.7.22)
# Requirement already satisfied: six in c:\users\jeet\anaconda3\lib\site-packages (from responses<0.19->datasets->imagen-pytorch) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jeet\anaconda3\lib\site-packages (from jinja2->torch>=1.6->imagen-pytorch) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jeet\anaconda3\lib\site-packages (from pandas->datasets->imagen-pytorch) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jeet\anaconda3\lib\site-packages (from pandas->datasets->imagen-pytorch) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jeet\anaconda3\lib\site-packages (from pandas->datasets->imagen-pytorch) (2023.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\jeet\anaconda3\lib\site-packages (from sympy->torch>=1.6->imagen-pytorch) (1.3.0)
# Downloading imagen_pytorch-1.26.2-py3-none-any.whl (63 kB)
#    ---------------------------------------- 0.0/63.6 kB ? eta -:--:--
#    ---------------------------------------- 63.6/63.6 kB ? eta 0:00:00
# Downloading accelerate-0.27.2-py3-none-any.whl (279 kB)
#    ---------------------------------------- 0.0/280.0 kB ? eta -:--:--
#    ----------------------------- ---------- 204.8/280.0 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 280.0/280.0 kB 5.7 MB/s eta 0:00:00
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.6 kB ? eta -:--:--
#    ---------------------------------------- 44.6/44.6 kB ? eta 0:00:00
# Downloading ema_pytorch-0.4.2-py3-none-any.whl (8.4 kB)
# Downloading pydantic-2.6.1-py3-none-any.whl (394 kB)
#    ---------------------------------------- 0.0/394.8 kB ? eta -:--:--
#    ------------------------------------ -- 368.6/394.8 kB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 394.8/394.8 kB 8.4 MB/s eta 0:00:00
# Downloading pydantic_core-2.16.2-cp311-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ------------ --------------------------- 0.6/1.9 MB 18.9 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.9 MB 12.7 MB/s eta 0:00:01
#    -------------------------------------- - 1.8/1.9 MB 14.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 13.4 MB/s eta 0:00:00
# Downloading beartype-0.17.2-py3-none-any.whl (872 kB)
#    ---------------------------------------- 0.0/872.4 kB ? eta -:--:--
#    --------------------------------------- 872.4/872.4 kB 18.3 MB/s eta 0:00:00
# Downloading kornia-0.7.1-py2.py3-none-any.whl (756 kB)
#    ---------------------------------------- 0.0/756.0 kB ? eta -:--:--
#    ----------------------------------- --- 696.3/756.0 kB 22.1 MB/s eta 0:00:01
#    --------------------------------------- 756.0/756.0 kB 16.2 MB/s eta 0:00:00
# Downloading pytorch_warmup-0.1.1-py3-none-any.whl (6.6 kB)
# Downloading sentencepiece-0.2.0-cp311-cp311-win_amd64.whl (991 kB)
#    ---------------------------------------- 0.0/991.5 kB ? eta -:--:--
#    --------------------------------------- 991.5/991.5 kB 20.9 MB/s eta 0:00:00
# Downloading torchvision-0.17.0-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -------------------------- ------------- 0.8/1.2 MB 24.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 25.1 MB/s eta 0:00:00
# Downloading torch-2.2.0-cp311-cp311-win_amd64.whl (198.6 MB)
#    ---------------------------------------- 0.0/198.6 MB ? eta -:--:--
#    ---------------------------------------- 1.0/198.6 MB 30.7 MB/s eta 0:00:07
#    ---------------------------------------- 2.0/198.6 MB 24.9 MB/s eta 0:00:08
#     --------------------------------------- 2.8/198.6 MB 22.7 MB/s eta 0:00:09
#     --------------------------------------- 4.2/198.6 MB 24.5 MB/s eta 0:00:08
#    - -------------------------------------- 5.3/198.6 MB 24.2 MB/s eta 0:00:08
#    - -------------------------------------- 6.3/198.6 MB 23.7 MB/s eta 0:00:09
#    - -------------------------------------- 7.4/198.6 MB 24.9 MB/s eta 0:00:08
#    - -------------------------------------- 8.5/198.6 MB 24.6 MB/s eta 0:00:08
#    - -------------------------------------- 9.5/198.6 MB 25.3 MB/s eta 0:00:08
#    -- ------------------------------------- 10.1/198.6 MB 23.8 MB/s eta 0:00:08
#    -- ------------------------------------- 10.9/198.6 MB 23.4 MB/s eta 0:00:09
#    -- ------------------------------------- 12.1/198.6 MB 23.4 MB/s eta 0:00:08
#    -- ------------------------------------- 12.8/198.6 MB 22.6 MB/s eta 0:00:09
#    -- ------------------------------------- 13.9/198.6 MB 23.4 MB/s eta 0:00:08
#    --- ------------------------------------ 14.9/198.6 MB 22.6 MB/s eta 0:00:09
#    --- ------------------------------------ 16.1/198.6 MB 22.6 MB/s eta 0:00:09
#    --- ------------------------------------ 17.1/198.6 MB 23.4 MB/s eta 0:00:08
#    --- ------------------------------------ 18.2/198.6 MB 23.4 MB/s eta 0:00:08
#    --- ------------------------------------ 19.2/198.6 MB 23.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 19.9/198.6 MB 22.6 MB/s eta 0:00:08
#    ---- ----------------------------------- 20.9/198.6 MB 23.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 21.9/198.6 MB 23.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 22.9/198.6 MB 25.2 MB/s eta 0:00:07
#    ---- ----------------------------------- 24.0/198.6 MB 24.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 25.1/198.6 MB 24.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 26.3/198.6 MB 24.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 27.3/198.6 MB 23.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 28.4/198.6 MB 23.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 29.3/198.6 MB 22.6 MB/s eta 0:00:08
#    ------ --------------------------------- 30.5/198.6 MB 23.4 MB/s eta 0:00:08
#    ------ --------------------------------- 31.6/198.6 MB 23.4 MB/s eta 0:00:08
#    ------ --------------------------------- 32.8/198.6 MB 23.4 MB/s eta 0:00:08
#    ------ --------------------------------- 33.9/198.6 MB 23.4 MB/s eta 0:00:08
#    ------- -------------------------------- 35.1/198.6 MB 24.2 MB/s eta 0:00:07
#    ------- -------------------------------- 36.2/198.6 MB 23.4 MB/s eta 0:00:07
#    ------- -------------------------------- 37.5/198.6 MB 24.3 MB/s eta 0:00:07
#    ------- -------------------------------- 38.7/198.6 MB 25.2 MB/s eta 0:00:07
#    -------- ------------------------------- 40.0/198.6 MB 26.2 MB/s eta 0:00:07
#    -------- ------------------------------- 41.3/198.6 MB 26.2 MB/s eta 0:00:07
#    -------- ------------------------------- 42.2/198.6 MB 26.2 MB/s eta 0:00:06
#    -------- ------------------------------- 43.5/198.6 MB 26.2 MB/s eta 0:00:06
#    -------- ------------------------------- 44.3/198.6 MB 25.2 MB/s eta 0:00:07
#    --------- ------------------------------ 45.7/198.6 MB 25.1 MB/s eta 0:00:07
#    --------- ------------------------------ 47.0/198.6 MB 26.2 MB/s eta 0:00:06
#    --------- ------------------------------ 48.2/198.6 MB 25.2 MB/s eta 0:00:06
#    --------- ------------------------------ 49.2/198.6 MB 26.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 50.4/198.6 MB 25.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 51.8/198.6 MB 26.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 52.9/198.6 MB 25.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 54.1/198.6 MB 25.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 55.2/198.6 MB 26.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 56.4/198.6 MB 26.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 57.5/198.6 MB 25.1 MB/s eta 0:00:06
#    ----------- ---------------------------- 58.7/198.6 MB 25.1 MB/s eta 0:00:06
#    ------------ --------------------------- 59.8/198.6 MB 25.2 MB/s eta 0:00:06
#    ------------ --------------------------- 60.8/198.6 MB 26.2 MB/s eta 0:00:06
#    ------------ --------------------------- 62.2/198.6 MB 26.2 MB/s eta 0:00:06
#    ------------ --------------------------- 63.0/198.6 MB 25.2 MB/s eta 0:00:06
#    ------------ --------------------------- 64.1/198.6 MB 25.2 MB/s eta 0:00:06
#    ------------- -------------------------- 65.2/198.6 MB 24.2 MB/s eta 0:00:06
#    ------------- -------------------------- 66.5/198.6 MB 25.2 MB/s eta 0:00:06
#    ------------- -------------------------- 67.8/198.6 MB 25.2 MB/s eta 0:00:06
#    ------------- -------------------------- 68.9/198.6 MB 25.2 MB/s eta 0:00:06
#    -------------- ------------------------- 70.0/198.6 MB 26.2 MB/s eta 0:00:05
#    -------------- ------------------------- 71.1/198.6 MB 25.2 MB/s eta 0:00:06
#    -------------- ------------------------- 72.0/198.6 MB 26.2 MB/s eta 0:00:05
#    -------------- ------------------------- 73.2/198.6 MB 26.2 MB/s eta 0:00:05
#    -------------- ------------------------- 74.4/198.6 MB 27.3 MB/s eta 0:00:05
#    --------------- ------------------------ 75.5/198.6 MB 27.3 MB/s eta 0:00:05
#    --------------- ------------------------ 76.7/198.6 MB 26.2 MB/s eta 0:00:05
#    --------------- ------------------------ 78.1/198.6 MB 26.2 MB/s eta 0:00:05
#    --------------- ------------------------ 78.9/198.6 MB 26.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 80.3/198.6 MB 27.3 MB/s eta 0:00:05
#    ---------------- ----------------------- 81.0/198.6 MB 26.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 82.2/198.6 MB 25.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 83.2/198.6 MB 26.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 84.4/198.6 MB 26.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 85.6/198.6 MB 26.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 86.8/198.6 MB 26.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 88.2/198.6 MB 26.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 89.3/198.6 MB 26.2 MB/s eta 0:00:05
#    ------------------ --------------------- 90.2/198.6 MB 26.2 MB/s eta 0:00:05
#    ------------------ --------------------- 91.4/198.6 MB 26.2 MB/s eta 0:00:05
#    ------------------ --------------------- 92.7/198.6 MB 27.3 MB/s eta 0:00:04
#    ------------------ --------------------- 93.7/198.6 MB 26.2 MB/s eta 0:00:05
#    ------------------- -------------------- 94.9/198.6 MB 26.2 MB/s eta 0:00:04
#    ------------------- -------------------- 96.1/198.6 MB 25.1 MB/s eta 0:00:05
#    ------------------- -------------------- 97.1/198.6 MB 26.2 MB/s eta 0:00:04
#    ------------------- -------------------- 98.5/198.6 MB 25.2 MB/s eta 0:00:04
#    -------------------- ------------------- 99.3/198.6 MB 27.3 MB/s eta 0:00:04
#    ------------------- ------------------- 100.1/198.6 MB 24.2 MB/s eta 0:00:05
#    ------------------- ------------------- 101.1/198.6 MB 24.3 MB/s eta 0:00:05
#    -------------------- ------------------ 102.3/198.6 MB 24.2 MB/s eta 0:00:04
#    -------------------- ------------------ 103.5/198.6 MB 24.2 MB/s eta 0:00:04
#    -------------------- ------------------ 104.6/198.6 MB 24.2 MB/s eta 0:00:04
#    -------------------- ------------------ 105.9/198.6 MB 24.2 MB/s eta 0:00:04
#    --------------------- ----------------- 107.0/198.6 MB 24.2 MB/s eta 0:00:04
#    --------------------- ----------------- 107.9/198.6 MB 24.2 MB/s eta 0:00:04
#    --------------------- ----------------- 108.3/198.6 MB 24.2 MB/s eta 0:00:04
#    --------------------- ----------------- 108.3/198.6 MB 24.2 MB/s eta 0:00:04
#    --------------------- ----------------- 108.3/198.6 MB 20.5 MB/s eta 0:00:05
#    --------------------- ----------------- 108.3/198.6 MB 20.5 MB/s eta 0:00:05
#    --------------------- ----------------- 108.3/198.6 MB 17.2 MB/s eta 0:00:06
#    --------------------- ----------------- 108.6/198.6 MB 15.2 MB/s eta 0:00:06
#    --------------------- ----------------- 109.3/198.6 MB 14.9 MB/s eta 0:00:07
#    --------------------- ----------------- 110.5/198.6 MB 15.6 MB/s eta 0:00:06
#    --------------------- ----------------- 111.8/198.6 MB 15.6 MB/s eta 0:00:06
#    ---------------------- ---------------- 112.9/198.6 MB 15.2 MB/s eta 0:00:06
#    ---------------------- ---------------- 113.7/198.6 MB 15.2 MB/s eta 0:00:06
#    ---------------------- ---------------- 115.0/198.6 MB 15.2 MB/s eta 0:00:06
#    ---------------------- ---------------- 115.8/198.6 MB 14.9 MB/s eta 0:00:06
#    ---------------------- ---------------- 116.9/198.6 MB 14.9 MB/s eta 0:00:06
#    ----------------------- --------------- 118.1/198.6 MB 15.2 MB/s eta 0:00:06
#    ----------------------- --------------- 119.4/198.6 MB 23.4 MB/s eta 0:00:04
#    ----------------------- --------------- 120.6/198.6 MB 23.4 MB/s eta 0:00:04
#    ----------------------- --------------- 121.6/198.6 MB 23.4 MB/s eta 0:00:04
#    ------------------------ -------------- 122.8/198.6 MB 23.4 MB/s eta 0:00:04
#    ------------------------ -------------- 124.0/198.6 MB 24.2 MB/s eta 0:00:04
#    ------------------------ -------------- 125.1/198.6 MB 25.2 MB/s eta 0:00:03
#    ------------------------ -------------- 126.1/198.6 MB 26.2 MB/s eta 0:00:03
#    ------------------------ -------------- 127.1/198.6 MB 26.2 MB/s eta 0:00:03
#    ------------------------- ------------- 128.1/198.6 MB 25.2 MB/s eta 0:00:03
#    ------------------------- ------------- 129.2/198.6 MB 26.2 MB/s eta 0:00:03
#    ------------------------- ------------- 130.4/198.6 MB 25.2 MB/s eta 0:00:03
#    ------------------------- ------------- 131.4/198.6 MB 26.2 MB/s eta 0:00:03
#    -------------------------- ------------ 132.4/198.6 MB 26.2 MB/s eta 0:00:03
#    -------------------------- ------------ 133.1/198.6 MB 25.2 MB/s eta 0:00:03
#    -------------------------- ------------ 134.0/198.6 MB 24.2 MB/s eta 0:00:03
#    -------------------------- ------------ 135.3/198.6 MB 24.2 MB/s eta 0:00:03
#    -------------------------- ------------ 136.5/198.6 MB 24.2 MB/s eta 0:00:03
#    --------------------------- ----------- 137.6/198.6 MB 24.2 MB/s eta 0:00:03
#    --------------------------- ----------- 138.6/198.6 MB 23.4 MB/s eta 0:00:03
#    --------------------------- ----------- 139.8/198.6 MB 23.4 MB/s eta 0:00:03
#    --------------------------- ----------- 140.8/198.6 MB 24.2 MB/s eta 0:00:03
#    --------------------------- ----------- 141.9/198.6 MB 23.4 MB/s eta 0:00:03
#    ---------------------------- ---------- 143.1/198.6 MB 25.1 MB/s eta 0:00:03
#    ---------------------------- ---------- 143.9/198.6 MB 25.2 MB/s eta 0:00:03
#    ---------------------------- ---------- 145.0/198.6 MB 25.1 MB/s eta 0:00:03
#    ---------------------------- ---------- 146.2/198.6 MB 25.1 MB/s eta 0:00:03
#    ---------------------------- ---------- 147.2/198.6 MB 24.3 MB/s eta 0:00:03
#    ----------------------------- --------- 148.0/198.6 MB 23.4 MB/s eta 0:00:03
#    ----------------------------- --------- 149.1/198.6 MB 23.4 MB/s eta 0:00:03
#    ----------------------------- --------- 149.9/198.6 MB 23.4 MB/s eta 0:00:03
#    ----------------------------- --------- 150.9/198.6 MB 22.6 MB/s eta 0:00:03
#    ----------------------------- --------- 152.1/198.6 MB 22.6 MB/s eta 0:00:03
#    ------------------------------ -------- 153.0/198.6 MB 21.8 MB/s eta 0:00:03
#    ------------------------------ -------- 154.0/198.6 MB 22.6 MB/s eta 0:00:02
#    ------------------------------ -------- 155.2/198.6 MB 22.6 MB/s eta 0:00:02
#    ------------------------------ -------- 156.5/198.6 MB 22.6 MB/s eta 0:00:02
#    ------------------------------ -------- 157.7/198.6 MB 23.4 MB/s eta 0:00:02
#    ------------------------------- ------- 158.8/198.6 MB 23.4 MB/s eta 0:00:02
#    ------------------------------- ------- 159.8/198.6 MB 23.4 MB/s eta 0:00:02
#    ------------------------------- ------- 161.1/198.6 MB 25.2 MB/s eta 0:00:02
#    ------------------------------- ------- 162.3/198.6 MB 25.2 MB/s eta 0:00:02
#    -------------------------------- ------ 163.5/198.6 MB 25.2 MB/s eta 0:00:02
#    -------------------------------- ------ 164.7/198.6 MB 25.2 MB/s eta 0:00:02
#    -------------------------------- ------ 165.4/198.6 MB 25.2 MB/s eta 0:00:02
#    -------------------------------- ------ 166.7/198.6 MB 25.2 MB/s eta 0:00:02
#    -------------------------------- ------ 167.6/198.6 MB 24.2 MB/s eta 0:00:02
#    --------------------------------- ----- 168.9/198.6 MB 25.1 MB/s eta 0:00:02
#    --------------------------------- ----- 170.1/198.6 MB 26.2 MB/s eta 0:00:02
#    --------------------------------- ----- 171.2/198.6 MB 25.2 MB/s eta 0:00:02
#    --------------------------------- ----- 172.5/198.6 MB 25.2 MB/s eta 0:00:02
#    ---------------------------------- ---- 173.7/198.6 MB 25.2 MB/s eta 0:00:01
#    ---------------------------------- ---- 174.9/198.6 MB 25.2 MB/s eta 0:00:01
#    ---------------------------------- ---- 175.9/198.6 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------- ---- 177.1/198.6 MB 26.2 MB/s eta 0:00:01
#    ----------------------------------- --- 178.4/198.6 MB 26.2 MB/s eta 0:00:01
#    ----------------------------------- --- 179.7/198.6 MB 26.2 MB/s eta 0:00:01
#    ----------------------------------- --- 180.9/198.6 MB 26.2 MB/s eta 0:00:01
#    ----------------------------------- --- 182.0/198.6 MB 26.2 MB/s eta 0:00:01
#    ----------------------------------- --- 183.3/198.6 MB 26.2 MB/s eta 0:00:01
#    ------------------------------------ -- 184.3/198.6 MB 26.2 MB/s eta 0:00:01
#    ------------------------------------ -- 185.3/198.6 MB 26.2 MB/s eta 0:00:01
#    ------------------------------------ -- 186.4/198.6 MB 26.2 MB/s eta 0:00:01
#    ------------------------------------ -- 187.7/198.6 MB 26.2 MB/s eta 0:00:01
#    ------------------------------------- - 189.0/198.6 MB 26.2 MB/s eta 0:00:01
#    ------------------------------------- - 190.1/198.6 MB 26.2 MB/s eta 0:00:01
#    ------------------------------------- - 191.2/198.6 MB 26.2 MB/s eta 0:00:01
#    ------------------------------------- - 192.4/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  193.6/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  194.9/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  195.9/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  197.2/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  198.3/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 26.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------- 198.6/198.6 MB 9.1 MB/s eta 0:00:00
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Installing collected packages: sentencepiece, typing-extensions, einops, beartype, annotated-types, torch, pydantic-core, torchvision, pytorch-warmup, pydantic, kornia, ema-pytorch, accelerate, imagen-pytorch
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.2
#     Uninstalling torch-2.1.2:
#       Successfully uninstalled torch-2.1.2
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Jeet\\anaconda3\\Lib\\site-packages\\~orch\\lib\\asmjit.dll'
# Consider using the `--user` option or check the permissions.
